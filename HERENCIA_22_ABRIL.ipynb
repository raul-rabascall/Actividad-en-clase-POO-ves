# %% [markdown]
# <a href="https://colab.research.google.com/github/raul-rabascall/Actividad-en-clase-POO-ves/blob/main/HERENCIA_22_ABRIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PERSONA

# %%
class Persona:
    def __init__(self, nombre, genero, edad=None, direccion=None):
        # Al asignar aquí, se invocan los setters definidos abajo
        self.nombre = nombre
        self.genero = genero
        self.edad = edad
        self.direccion = direccion

    # --- Propiedad: nombre ---
    @property
    def nombre(self):
        return self.__nombre

    @nombre.setter
    def nombre(self, valor):
        self.__nombre = valor

    # --- Propiedad: genero ---
    @property
    def genero(self):
        return self.__genero

    @genero.setter
    def genero(self, valor):
        self.__genero = valor

    # --- Propiedad: edad con validacion >18 ---

    @property
    def edad(self):
        return self.__edad

    @edad.setter
    def edad(self, valor):
        if valor is not None and valor < 18:
            raise ValueError("Error: La edad debe ser mauyor o igual a 18.")
        self.__edad = valor

    # --- Propiedad: direccion ---
    @property
    def direccion(self):
        return self.__direccion

    @direccion.setter
    def direccion(self, valor):
        self.__direccion = valor

    # --- Método Especial __str__ ---
    def __str__(self):
        # __dict__ mostrará los nombres deformados por el doble guion bajo
        return f"Datos de la Persona: {self.__dict__}"

# --- Pruebas ---
if __name__ == "__main__":

#1 Creacion exitosa con (atributos ocacionales)
p1= Persona("Carlos", "Masculino",25, "Av Siempre Vivas 74")
print(f"Persona 1: {p1}")


#2 Creacion exitosa sin (atributos ocacionales)
print(p1)

p1 = Persona("Roberto", "Masculino", 17)
except ValueError as e:
print(e)

# Creación correcta
p2 = Persona("Lucía", "Femenino", 22)
print(p2)

# La dirección es opcional
p3 = Persona("Marco", "Masculino", 30, "Calle Luna 456")
print(p3)
# Out:
#   File "/tmp/ipykernel_41281/4065696767.py", line 57
#     p1= Persona("Carlos", "Masculino",25, "Av Siempre Vivas 74")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 54

# %% [markdown]
# EMPLEADO

# %%
from persona import Persona


class Empleado (Persona):
    def __init__(self, nombre, genero, edad=None, direccion=None, idEmpleado=None, sueldo=None):
        Persona.__init__(self, nombre, genero, edad, direccion)
        self.idEmpleado = idEmpleado
        self.sueldo = sueldo


    @property
    def idEmpleado(self):
        return self.__idEmpleado

    @idEmpleado.setter
    def idEmpleado(self, valor):
        self.__idEmpleado = valor

    @property
    def sueldo(self):
        return self.__sueldo

    @sueldo.setter
    def sueldo(self, valor):
        if valor < 0:
            raise ValueError("Error: Sueldo no pude ser negativo")
        self.__sueldo = valor

if __name__ == "__main__":
    e1 = Empleado(nombre="Luis", genero="Masculino", edad=20,)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_41281/989559971.py in <cell line: 0>()
# ----> 1 from persona import Persona
#       2
#       3
#       4 class Empleado (Persona):
#       5     def __init__(self, nombre, genero, edad=None, direccion=None, idEmpleado=None, sueldo=None):
#
# ModuleNotFoundError: No module named 'persona'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# CLIENTE

# %%
from perfmon import Persona


class Cliente(Persona):
  def __init__(self, nombre, genero, edad=None, direccion=None, idCliente=None, vip=False, fechaRegistro=none):
    Persona.__init__(self, nombre, genero, edad, direccion)
    self.idCliente = idCliente
    self.vip = vip
    self.fechaRegistro = fechaRegistro

  @property
  def idCliente(self):
    return self.__idCliente

  @idCliente.setter
  def idCliente(self, valor):
    self.__idCliente = valor

  @property
  def vip(self):
    return self.__vip

  @vip.setter
  def vip(self, valor):
    self.__vip = valor

  @property
  def fechaRegistro(self):
    return self.__fechaRegistro
  @fechaRegistro.setter
  def fechaRegistro(self, valor):
    self.__fechaRegistro = valor
if __name__ == "__main__":
  c1 = Cliente(nombre="Carlos", genero="Masculino", edad=18, direccion="Sur",idCliente=1, vip=True, fechaRegistro="22/04/2026")
